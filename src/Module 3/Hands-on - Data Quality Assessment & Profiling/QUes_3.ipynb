# %%
# Part 1: Load a Dataset & Check Missing Values

# Task 1: Iris Dataset
# - Load the dataset using Pandas.
# - Check for missing values in the entire dataset.

import pandas as pd
import seaborn as sns



# Save report if needed
# data_quality_report.to_csv("data_quality_report.csv")
import pandas as pd
import seaborn as sns

# -------------------------------
# Part 1: Load Dataset & Check Missing Values
# -------------------------------

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Display first few rows
print("📊 First 5 rows of the dataset:")
print(iris.head())

# Check for missing values
print("\n🔍 Missing Values in Iris Dataset:")
print(iris.isnull().sum())

# -------------------------------
# Part 2: Identify Duplicates & Inconsistencies
# -------------------------------

# For demonstration, create a mock dataset with inconsistent gender values
sample_df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Gender': ['Male', 'M', 'male', 'F', 'Female']
})

# View original entries
print("\n👤 Sample Gender Column (Before Standardization):")
print(sample_df)

# Normalize gender values (example transformation logic)
sample_df['Gender_cleaned'] = sample_df['Gender'].str.strip().str.lower().map({
    'male': 'Male', 'm': 'Male',
    'female': 'Female', 'f': 'Female'
})

print("\n🧹 Cleaned Gender Column:")
print(sample_df[['Name', 'Gender', 'Gender_cleaned']])

# -------------------------------
# Part 3: Generate Data Quality Report
# -------------------------------

# Basic statistics for the Iris dataset
print("\n📈 Descriptive Statistics for Iris Dataset:")
print(iris.describe(include='all'))

# Optionally: Save report to CSV
# iris.describe().to_csv("iris_data_quality_report.csv")






# Part 2: Identify Duplicates & Inconsistencies

# Task 2: Inconsistent Entries in a Sample Dataset
# - Assume you have a dataset with a 'Gender' column. Identify inconsistent entries like 'M', 'Male', or 'male'.



import pandas as pd
import seaborn as sns

# -------------------------------
# Part 1: Load Dataset & Check Missing Values
# -------------------------------

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Display first few rows
print("📊 First 5 rows of the dataset:")
print(iris.head())

# Check for missing values
print("\n🔍 Missing Values in Iris Dataset:")
print(iris.isnull().sum())

# -------------------------------
# Part 2: Identify Duplicates & Inconsistencies
# -------------------------------

# For demonstration, create a mock dataset with inconsistent gender values
sample_df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Gender': ['Male', 'M', 'male', 'F', 'Female']
})

# View original entries
print("\n👤 Sample Gender Column (Before Standardization):")
print(sample_df)

# Normalize gender values (example transformation logic)
sample_df['Gender_cleaned'] = sample_df['Gender'].str.strip().str.lower().map({
    'male': 'Male', 'm': 'Male',
    'female': 'Female', 'f': 'Female'
})

print("\n🧹 Cleaned Gender Column:")
print(sample_df[['Name', 'Gender', 'Gender_cleaned']])

# -------------------------------
# Part 3: Generate Data Quality Report
# -------------------------------

# Basic statistics for the Iris dataset
print("\n📈 Descriptive Statistics for Iris Dataset:")
print(iris.describe(include='all'))

# Optionally: Save report to CSV
# iris.describe().to_csv("iris_data_quality_report.csv")






# Part 3: Generate a Data Quality Report

# Task 3: Iris Dataset Summary
# - Generate basic descriptive statistics for the Iris dataset.


import pandas as pd
import seaborn as sns

# -------------------------------
# Part 1: Load Dataset & Check Missing Values
# -------------------------------

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Display first few rows
print("📊 First 5 rows of the dataset:")
print(iris.head())

# Check for missing values
print("\n🔍 Missing Values in Iris Dataset:")
print(iris.isnull().sum())

# -------------------------------
# Part 2: Identify Duplicates & Inconsistencies
# -------------------------------

# For demonstration, create a mock dataset with inconsistent gender values
sample_df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Gender': ['Male', 'M', 'male', 'F', 'Female']
})

# View original entries
print("\n👤 Sample Gender Column (Before Standardization):")
print(sample_df)

# Normalize gender values (example transformation logic)
sample_df['Gender_cleaned'] = sample_df['Gender'].str.strip().str.lower().map({
    'male': 'Male', 'm': 'Male',
    'female': 'Female', 'f': 'Female'
})

print("\n🧹 Cleaned Gender Column:")
print(sample_df[['Name', 'Gender', 'Gender_cleaned']])

# -------------------------------
# Part 3: Generate Data Quality Report
# -------------------------------

# Basic statistics for the Iris dataset
print("\n📈 Descriptive Statistics for Iris Dataset:")
print(iris.describe(include='all'))

# Optionally: Save report to CSV
# iris.describe().to_csv("iris_data_quality_report.csv")
# Out:
# 📊 First 5 rows of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# 🔍 Missing Values in Iris Dataset:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# 👤 Sample Gender Column (Before Standardization):
#       Name  Gender
# 0    Alice    Male
# 1      Bob       M
# 2  Charlie    male
# 3    David       F
# 4      Eve  Female
#
# 🧹 Cleaned Gender Column:
#       Name  Gender Gender_cleaned
# 0    Alice    Male           Male
# 1      Bob       M           Male
# 2  Charlie    male           Male
# 3    David       F         Female
# ...
